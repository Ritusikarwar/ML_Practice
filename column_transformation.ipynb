# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv("C:\\Users\\Dell\\Downloads\\datasets\\Disease_Dataset.csv")
df.head()
# Out:
#    age  gender   bmi smoking_status alcohol_consumption exercise_level  \
# 0   79    Male  24.8         Former                 NaN         Active
# 1   77  Female  39.9         Former            Moderate          Light
# 2   24    Male  26.4         Former               Heavy       Moderate
# 3   69    Male  23.1          Never               Heavy       Moderate
# 4   63    Male  29.6          Never                 NaN       Moderate
#
#     diet_type sun_exposure income_level latitude_region  ...  \
# 0  Vegetarian         High         High             Mid  ...
# 1    Omnivore          Low          Low             Low  ...
# 2    Omnivore          Low         High            High  ...
# 3  Vegetarian         High          Low             Low  ...
# 4  Vegetarian     Moderate         High             Low  ...
#
#    has_night_blindness  has_fatigue  has_bleeding_gums  has_bone_pain  \
# 0                    0            0                  0              0
# ...

# %% [markdown]
# Extracting meaningful columns

# %%
columns_to_drop=['has_night_blindness','has_fatigue','has_bleeding_gums','has_bone_pain','has_muscle_weakness','has_numbness_tingling','has_memory_problems','has_pale_skin','has_multiple_deficiencies']
df=df.drop(columns=columns_to_drop)
df.head()
# Out:
#    age  gender   bmi smoking_status alcohol_consumption exercise_level  \
# 0   79    Male  24.8         Former                 NaN         Active
# 1   77  Female  39.9         Former            Moderate          Light
# 2   24    Male  26.4         Former               Heavy       Moderate
# 3   69    Male  23.1          Never               Heavy       Moderate
# 4   63    Male  29.6          Never                 NaN       Moderate
#
#     diet_type sun_exposure income_level latitude_region  ...  \
# 0  Vegetarian         High         High             Mid  ...
# 1    Omnivore          Low          Low             Low  ...
# 2    Omnivore          Low         High            High  ...
# 3  Vegetarian         High          Low             Low  ...
# 4  Vegetarian     Moderate         High             Low  ...
#
#    folate_percent_rda  calcium_percent_rda  iron_percent_rda  hemoglobin_g_dl  \
# 0               188.9                108.3              97.4             13.5
# ...

# %%
columns_to_drop=["diet_type","sun_exposure","income_level","latitude_region","folate_percent_rda","calcium_percent_rda","iron_percent_rda","hemoglobin_g_dl","serum_vitamin_d_ng_ml","serum_vitamin_b12_pg_ml","serum_folate_ng_ml","symptoms_count"]
df=df.drop(columns=columns_to_drop)
df.head()
# Out:
#    age  gender   bmi smoking_status alcohol_consumption exercise_level  \
# 0   79    Male  24.8         Former                 NaN         Active
# 1   77  Female  39.9         Former            Moderate          Light
# 2   24    Male  26.4         Former               Heavy       Moderate
# 3   69    Male  23.1          Never               Heavy       Moderate
# 4   63    Male  29.6          Never                 NaN       Moderate
#
#    vitamin_a_percent_rda  vitamin_c_percent_rda  vitamin_d_percent_rda  \
# 0                  119.1                  147.3                 152.88
# 1                   85.7                   57.5                  32.76
# 2                   48.3                  152.1                  94.99
# 3                   75.8                   51.0                  51.48
# 4                   93.3                  111.5                  62.90
#
#    vitamin_e_percent_rda  vitamin_b12_percent_rda  \
# 0                   97.5                    102.5
# ...

# %%
columns_to_drop=['vitamin_a_percent_rda','vitamin_c_percent_rda','vitamin_d_percent_rda','vitamin_e_percent_rda','vitamin_b12_percent_rda']
df=df.drop(columns=columns_to_drop)
df.head()
# Out:
#    age  gender   bmi smoking_status alcohol_consumption exercise_level  \
# 0   79    Male  24.8         Former                 NaN         Active
# 1   77  Female  39.9         Former            Moderate          Light
# 2   24    Male  26.4         Former               Heavy       Moderate
# 3   69    Male  23.1          Never               Heavy       Moderate
# 4   63    Male  29.6          Never                 NaN       Moderate
#
#                        symptoms_list     disease_diagnosis
# 0                                NaN               Healthy
# 1                          bone_pain  Rickets_Osteomalacia
# 2           dry_skin;night_blindness               Healthy
# 3  numbness_tingling;memory_problems                Anemia
# 4                                NaN               Healthy

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  4000 non-null   int64
#  1   gender               4000 non-null   str
#  2   bmi                  4000 non-null   float64
#  3   smoking_status       4000 non-null   str
#  4   alcohol_consumption  2722 non-null   str
#  5   exercise_level       4000 non-null   str
#  6   symptoms_list        2672 non-null   str
#  7   disease_diagnosis    4000 non-null   str
# dtypes: float64(1), int64(1), str(6)
# memory usage: 250.1 KB

# %% [markdown]
# Dealing with NAN values

# %%
df['alcohol_consumption'] = df['alcohol_consumption'].fillna('Unknown')
df['symptoms_list'] = df['symptoms_list'].fillna('Unknown')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  4000 non-null   int64
#  1   gender               4000 non-null   str
#  2   bmi                  4000 non-null   float64
#  3   smoking_status       4000 non-null   str
#  4   alcohol_consumption  4000 non-null   str
#  5   exercise_level       4000 non-null   str
#  6   symptoms_list        4000 non-null   str
#  7   disease_diagnosis    4000 non-null   str
# dtypes: float64(1), int64(1), str(6)
# memory usage: 250.1 KB

# %%
df["disease_diagnosis"].value_counts()
# Out:
# disease_diagnosis
# Healthy                 1509
# Anemia                  1245
# Rickets_Osteomalacia    1029
# Night_Blindness          122
# Scurvy                    95
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    age  gender   bmi smoking_status alcohol_consumption exercise_level  \
# 0   79    Male  24.8         Former             Unknown         Active
# 1   77  Female  39.9         Former            Moderate          Light
# 2   24    Male  26.4         Former               Heavy       Moderate
# 3   69    Male  23.1          Never               Heavy       Moderate
# 4   63    Male  29.6          Never             Unknown       Moderate
#
#                        symptoms_list     disease_diagnosis
# 0                            Unknown               Healthy
# 1                          bone_pain  Rickets_Osteomalacia
# 2           dry_skin;night_blindness               Healthy
# 3  numbness_tingling;memory_problems                Anemia
# 4                            Unknown               Healthy

# %% [markdown]
# Train test splitting

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns=["disease_diagnosis"]),df["disease_diagnosis"],test_size=0.2,random_state=42)
y_train
# Out:
# 3994                 Healthy
# 423                  Healthy
# 2991         Night_Blindness
# 1221    Rickets_Osteomalacia
# 506                  Healthy
#                 ...
# 1130    Rickets_Osteomalacia
# 1294    Rickets_Osteomalacia
# 860                   Anemia
# 3507                 Healthy
# 3174                 Healthy
# Name: disease_diagnosis, Length: 3200, dtype: str
